# %%
import numpy as np
import pandas as pd
import pickle
import warnings;warnings.simplefilter('ignore')

# %%
################################################ Load Data ######################################################
df_1 = pd.read_excel('INPUTS_1.xlsx',index_col=0)
df_2 = pd.read_excel('INPUTS_2.xlsx',index_col=0)
df_3 = pd.read_excel('INPUTS_3.xlsx',index_col=0)
df_4 = pd.read_excel('INPUTS_4.xlsx',index_col=0)
df = pd.concat([df_1, df_2, df_3, df_4])
df
# Out:
#        molecule    mass  polarity  ads_flex  BalabanJ   BertzCT       Ipc  \
# 0        [H][H]   2.016         0         0  1.000000  0.000000  2.000000
# 1        [H][H]   2.016         0         0  1.000000  0.000000  2.000000
# 2        [H][H]   2.016         0         0  1.000000  0.000000  2.000000
# 3        [H][H]   2.016         0         0  1.000000  0.000000  2.000000
# 4        [H][H]   2.016         0         0  1.000000  0.000000  2.000000
# ...         ...     ...       ...       ...       ...       ...       ...
# 255199     CCCO  60.000         1         1  1.974745  5.245112  6.854753
# 255200     CCCO  60.000         1         1  1.974745  5.245112  6.854753
# 255201     CCCO  60.000         1         1  1.974745  5.245112  6.854753
# 255202     CCCO  60.000         1         1  1.974745  5.245112  6.854753
# 255203     CCCO  60.000         1         1  1.974745  5.245112  6.854753
#
#         HallKierAlpha      Chi0      Chi1  ...           m11           m12  \
# 0                0.00  2.000000  1.000000  ...  9.289127e-16  8.185727e-35
# 1                0.00  2.000000  1.000000  ...  3.340460e+01  4.041058e+01
# 2                0.00  2.000000  1.000000  ...  3.541310e+01  4.312715e+01
# 3                0.00  2.000000  1.000000  ...  1.465996e+01  1.934449e+01
# 4                0.00  2.000000  1.000000  ...  7.508367e+00  1.409638e+00
# ...               ...       ...       ...  ...           ...           ...
# 255199          -0.04  3.414214  1.914214  ...  1.613924e-58  2.904773e-94
# 255200          -0.04  3.414214  1.914214  ...  2.799033e+01  1.999164e+01
# 255201          -0.04  3.414214  1.914214  ...  5.010007e-02  7.417221e-10
# 255202          -0.04  3.414214  1.914214  ...  3.641598e+00  3.270261e-03
# 255203          -0.04  3.414214  1.914214  ...  3.324705e+01  1.282098e+01
#
#                   m13            m14            m15            m16  \
# 0        1.567010e-62   6.244086e-99  5.138946e-144  8.721329e-198
# 1        3.144139e+01   3.760311e+01   2.992777e+01   4.788616e+01
# 2        3.111661e+01   4.000298e+01   3.070083e+01   4.853047e+01
# 3        2.326113e+01   2.383980e+01   2.095139e+01   1.681630e+01
# 4        4.408495e-01   1.009733e-08   1.835888e-24   1.491179e-48
# ...               ...            ...            ...            ...
# 255199  1.077611e-138  8.239921e-192  1.298657e-253   0.000000e+00
# 255200   6.363571e+00   7.814230e-01   5.573205e-05   3.683415e-17
# 255201   3.799395e-26   4.035351e-51   8.869075e-85  4.033151e-127
# 255202   2.535952e-13   4.091221e-32   1.360440e-59   9.324294e-96
# 255203   9.677083e+00   5.471993e+00   2.581107e+00   1.333508e+00
#
#                   m17            m18            m19            m20
# 0       3.051009e-260   0.000000e+00   0.000000e+00   0.000000e+00
# 1        2.766322e+01   2.035345e+01   1.012500e+01   9.823590e+00
# 2        2.677733e+01   1.813301e+01   9.076279e+00   9.714936e+00
# 3        1.233812e+01   1.061592e+01   6.828671e+00   4.809042e+00
# 4        2.823296e-81  1.128743e-122  9.388707e-173  1.616817e-231
# ...               ...            ...            ...            ...
# 255199   0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 255200   6.009738e-38   2.176171e-67  1.681285e-105  2.734420e-152
# 255201  3.794165e-178  7.382804e-238  2.970852e-306   0.000000e+00
# 255202  1.317234e-140  3.835487e-194  2.301910e-256   0.000000e+00
# 255203   1.401829e-01   9.425061e-01   5.774930e-08   7.293226e-24
#
# [255204 rows x 96 columns]

# %% [markdown]
# # Classification

# %%
################################################ prepare data ######################################################
drop_cols = ['molecule', 'MOF', 'Chi0', 'Kappa1', 'NumValenceElectrons',
       'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20',
       'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10', 'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
       'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12', 'm13', 'm14', 'm15', 'm16', 'm17', 'm18', 'm19', 'm20']
x_clf = df.drop(columns=drop_cols).values
print('X matrix dimensions: {}'.format(x_clf.shape))


############################################## load classification model ######################################################
pickled_classifier = pickle.load(open('trained_classification_model_knn.pkl', 'rb'))
scaler_c = pickle.load(open('scaler_c.pkl','rb'))
lda = pickle.load(open('lda.pkl','rb'))


################################################### classify ########################################################
x_clf_scaled = scaler_c.transform(x_clf)
x_clf_lda = lda.transform(x_clf_scaled)
y_clf = pickled_classifier.predict(x_clf_lda)
df.insert(loc=0, column='IFF', value=y_clf)
df[['IFF', 'molecule', 'MOF']]
# Out:
# X matrix dimensions: (255204, 34)
#         IFF molecule           MOF
# 0      -1.0   [H][H]  ABAVIJ_clean
# 1      -1.0   [H][H]  ABAYIO_clean
# 2      -1.0   [H][H]  ABAYOU_clean
# 3      -1.0   [H][H]  ABETIN_clean
# 4       0.0   [H][H]  ABEXEM_clean
# ...     ...      ...           ...
# 255199 -1.0     CCCO  ZUTBIB_clean
# 255200  1.0     CCCO  ZUTBUN_clean
# 255201 -1.0     CCCO  ZUVTEP_clean
# 255202  1.0     CCCO  ZUWWAP_clean
# 255203 -1.0     CCCO  ZUWXUM_clean
#
# [255204 rows x 3 columns]

# %% [markdown]
# # Prediction

# %%
############################################### prepare data ######################################################
negligibles = df.index[np.where(df.IFF == 0)]
df0 = df.loc[negligibles]
drop_cols = ['molecule', 'MOF','IFF'] 
x_pred = df0.drop(columns=drop_cols).values
print('X matrix dimensions: {}'.format(x_pred.shape))

############################################## load regression model ######################################################
pickled_regresser = pickle.load(open('trained_regression_model_gbr.pkl', 'rb'))
scaler_r = pickle.load(open('scaler_r.pkl','rb'))


################################################### classify ########################################################
x_pred_scaled = scaler_r.transform(x_pred)
y_pred = pickled_regresser.predict(x_pred_scaled)
df_Ds = df0
df_Ds.insert(loc=1, column='Ds', value=10**y_pred)
df_Ds[['IFF', 'molecule', 'MOF', 'Ds']]
# Out:
# X matrix dimensions: (70442, 94)
#         IFF molecule                                           MOF        Ds
# 4       0.0   [H][H]                                  ABEXEM_clean  0.000504
# 35      0.0   [H][H]  acs.inorgchem.6b00276_ic6b00276_si_006_clean  0.000918
# 42      0.0   [H][H]  acs.inorgchem.6b01740_ic6b01740_si_002_clean  0.002359
# 46      0.0   [H][H]  acs.inorgchem.6b02696_ic6b02696_si_002_clean  0.000963
# 51      0.0   [H][H]                acscombsci.5b00188_34903_clean  0.001872
# ...     ...      ...                                           ...       ...
# 255038  0.0     CCCO                                  YUZPOA_clean  0.000297
# 255076  0.0     CCCO                                  ZAZNUL_clean  0.000094
# 255177  0.0     CCCO                                  ZUBFIN_clean  0.000050
# 255178  0.0     CCCO                                  ZUCKIT_clean  0.000158
# 255196  0.0     CCCO                                  ZUSNOS_clean  0.000148
#
# [70442 rows x 4 columns]
